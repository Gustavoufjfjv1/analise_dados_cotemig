# %%
import pandas as pd
import openpyxl

# %%
path = r"H:\Python\analise_dados\atividade 4\CD2022_Populacao_2010_Compatibilizada_20231222.xlsx"

# %%
bruto = pd.read_excel(path, header=2)

# %%
bruto
# Out:
#       Unnamed: 0                                                 UF  COD. UF  \
# 0            NaN                                                 RO     11.0
# 1            NaN                                                 RO     11.0
# 2            NaN                                                 RO     11.0
# 3            NaN                                                 RO     11.0
# 4            NaN                                                 RO     11.0
# ...          ...                                                ...      ...
# 5569         NaN                                                 DF     53.0
# 5570         NaN                                                NaN      NaN
# 5571         NaN  Nota: Para o cálculo das taxas de crescimento ...      NaN
# 5572         NaN                                                NaN      NaN
# 5573         NaN  Fonte: IBGE. Diretoria de Pesquisas - DPE -  C...      NaN
#
# ...

# %%
formatado = bruto.iloc[:5570, 1:]
formatado
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  \
# 0     RO     11.0        15.0  Alta Floresta D'Oeste
# 1     RO     11.0        23.0              Ariquemes
# 2     RO     11.0        31.0                 Cabixi
# 3     RO     11.0        49.0                 Cacoal
# 4     RO     11.0        56.0             Cerejeiras
# ...   ..      ...         ...                    ...
# 5565  GO     52.0     22005.0             Vianópolis
# 5566  GO     52.0     22054.0         Vicentinópolis
# 5567  GO     52.0     22203.0               Vila Boa
# 5568  GO     52.0     22302.0          Vila Propício
# 5569  DF     53.0       108.0               Brasília
#
#       População Município 2010\n(Sinopse)  \
# 0                                 24392.0
# 1                                 90353.0
# 2                                  6313.0
# 3                                 78574.0
# 4                                 17029.0
# ...                                   ...
# ...

# %%
formatado.columns
# Out:
# Index(['UF', 'COD. UF', 'COD. MUNIC', 'NOME DO MUNICÍPIO',
#        'População Município 2010\n(Sinopse)',
#        'População 2010 (Alterações de Limites até 2022)1',
#        'População Censo 2022'],
#       dtype='str')

# %%
formatado["diferença"] = formatado["População Censo 2022"] - formatado["População Município 2010\n(Sinopse)"]

# %%
porEstado = formatado.groupby("UF")[['População Município 2010\n(Sinopse)', 'População Censo 2022', "diferença"]].sum().reset_index()

# %%
porEstado
# Out:
#     UF  População Município 2010\n(Sinopse)  População Censo 2022  diferença
# 0   AC                             733559.0              830018.0    96459.0
# 1   AL                            3120494.0             3127683.0     7189.0
# 2   AM                            3483985.0             3941613.0   457628.0
# 3   AP                             669526.0              733759.0    64233.0
# 4   BA                           14016906.0            14141626.0   124720.0
# 5   CE                            8452381.0             8794957.0   342576.0
# 6   DF                            2570160.0             2817381.0   247221.0
# 7   ES                            3514952.0             3833712.0   318760.0
# 8   GO                            6003788.0             7056495.0  1052707.0
# 9   MA                            6574789.0             6776699.0   201910.0
# 10  MG                           19597330.0            20539989.0   942659.0
# ...

# %%
porEstado = porEstado.sort_values(by="diferença", ascending=False)
porEstado = porEstado.reset_index(drop=True)
porEstado.to_csv(r"H:\Python\analise_dados\atividade 4/formatadoPorCrescimentoEstado.xlsx", sep =";")

# %%
porEstado
# Out:
#     UF  População Município 2010\n(Sinopse)  População Censo 2022  diferença
# 0   SP                           41262199.0            44411238.0  3149039.0
# 1   SC                            6248436.0             7610361.0  1361925.0
# 2   GO                            6003788.0             7056495.0  1052707.0
# 3   PR                           10444526.0            11444380.0   999854.0
# 4   MG                           19597330.0            20539989.0   942659.0
# 5   MT                            3035122.0             3658649.0   623527.0
# 6   PA                            7581051.0             8120131.0   539080.0
# 7   AM                            3483985.0             3941613.0   457628.0
# 8   CE                            8452381.0             8794957.0   342576.0
# 9   ES                            3514952.0             3833712.0   318760.0
# 10  MS                            2449024.0             2757013.0   307989.0
# ...

# %%
porMunicipo = formatado.sort_values(by="diferença", ascending=False)
porMunicipo = porMunicipo.reset_index(drop=True)
porMunicipo.to_csv(r"H:\Python\analise_dados\atividade 4/formatadoPorCrescimentoMunicipio.xlsx", sep =";")

# %%
porMunicipo
# Out:
#       UF  COD. UF  COD. MUNIC NOME DO MUNICÍPIO  \
# 0     AM     13.0      2603.0            Manaus
# 1     DF     53.0       108.0          Brasília
# 2     SP     35.0     50308.0         São Paulo
# 3     SP     35.0     52205.0          Sorocaba
# 4     GO     52.0      8707.0           Goiânia
# ...   ..      ...         ...               ...
# 5565  RS     43.0     14902.0      Porto Alegre
# 5566  PA     15.0      1402.0             Belém
# 5567  RJ     33.0      4904.0       São Gonçalo
# 5568  RJ     33.0      4557.0    Rio de Janeiro
# 5569  BA     29.0     27408.0          Salvador
#
#       População Município 2010\n(Sinopse)  \
# 0                               1802014.0
# 1                               2570160.0
# 2                              11253503.0
# 3                                586625.0
# 4                               1302001.0
# ...                                   ...
# 5565                            1409351.0
# ...
